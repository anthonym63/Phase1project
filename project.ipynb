# %% [markdown]
# This notebook is divided into two parts, exploration and analysis in which we clean and analyse the data indepth inorder to give a clear recomendation

# %%
import pandas as pd

# %% [markdown]
# ### 1. Data Exploration and Cleaning

# %%
df = pd.read_csv("Aviation_Data.csv")
# Out:
# c:\Users\USER\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Brief summary of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
#  14  Make                    88826 non-null  object
#  15  Model                   88797 non-null  object
#  16  Amateur.Built           88787 non-null  object
#  17  Number.of.Engines       82805 non-null  float64
#  18  Engine.Type             81812 non-null  object
#  19  FAR.Description         32023 non-null  object
#  20  Schedule                12582 non-null  object
#  21  Purpose.of.flight       82697 non-null  object
#  22  Air.carrier             16648 non-null  object
#  23  Total.Fatal.Injuries    77488 non-null  float64
#  24  Total.Serious.Injuries  76379 non-null  float64
#  25  Total.Minor.Injuries    76956 non-null  float64
#  26  Total.Uninjured         82977 non-null  float64
#  27  Weather.Condition       84397 non-null  object
#  28  Broad.phase.of.flight   61724 non-null  object
#  29  Report.Status           82508 non-null  object
#  30  Publication.Date        73659 non-null  object
# dtypes: float64(5), object(26)
# memory usage: 21.4+ MB

# %% [markdown]
# Checking for total number of missing values in each column.

# %%
df.isna().sum()
# Out:
# Event.Id                   1459
# Investigation.Type            0
# Accident.Number            1459
# Event.Date                 1459
# Location                   1511
# Country                    1685
# Latitude                  55966
# Longitude                 55975
# Airport.Code              40099
# Airport.Name              37558
# Injury.Severity            2459
# Aircraft.damage            4653
# Aircraft.Category         58061
# Registration.Number        2776
# Make                       1522
# Model                      1551
# Amateur.Built              1561
# Number.of.Engines          7543
# Engine.Type                8536
# FAR.Description           58325
# Schedule                  77766
# Purpose.of.flight          7651
# Air.carrier               73700
# Total.Fatal.Injuries      12860
# Total.Serious.Injuries    13969
# Total.Minor.Injuries      13392
# Total.Uninjured            7371
# Weather.Condition          5951
# Broad.phase.of.flight     28624
# Report.Status              7840
# Publication.Date          16689
# dtype: int64

# %% [markdown]
# Checking for total number of duplicate values.

# %%
df.duplicated().sum()
# Out:
# 1390

# %% [markdown]
# Dropping all duplicate values.

# %%
df.drop_duplicates()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Latitude Longitude Airport.Code  \
# 0      MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1       BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2        Saltville, VA  United States  36.9222  -81.8781          NaN
# 3           EUREKA, CA  United States      NaN       NaN          NaN
# 4           Canton, OH  United States      NaN       NaN          NaN
# ...                ...            ...      ...       ...          ...
# 90343    Annapolis, MD  United States      NaN       NaN          NaN
# 90344      Hampton, NH  United States      NaN       NaN          NaN
# 90345       Payson, AZ  United States  341525N  1112021W          PAN
# 90346       Morgan, UT  United States      NaN       NaN          NaN
# 90347       Athens, GA  United States      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 0              NaN  ...          Personal                 NaN
# 1              NaN  ...          Personal                 NaN
# 2              NaN  ...          Personal                 NaN
# 3              NaN  ...          Personal                 NaN
# 4              NaN  ...          Personal                 NaN
# ...            ...  ...               ...                 ...
# 90343          NaN  ...          Personal                 NaN
# 90344          NaN  ...               NaN                 NaN
# 90345       PAYSON  ...          Personal                 NaN
# 90346          NaN  ...          Personal  MC CESSNA 210N LLC
# 90347          NaN  ...          Personal                 NaN
#
#       Total.Fatal.Injuries Total.Serious.Injuries Total.Minor.Injuries  \
# 0                      2.0                    0.0                  0.0
# 1                      4.0                    0.0                  0.0
# 2                      3.0                    NaN                  NaN
# 3                      2.0                    0.0                  0.0
# 4                      1.0                    2.0                  NaN
# ...                    ...                    ...                  ...
# 90343                  0.0                    1.0                  0.0
# 90344                  0.0                    0.0                  0.0
# 90345                  0.0                    0.0                  0.0
# 90346                  0.0                    0.0                  0.0
# 90347                  0.0                    1.0                  0.0
#
#       Total.Uninjured Weather.Condition  Broad.phase.of.flight  \
# 0                 0.0               UNK                 Cruise
# 1                 0.0               UNK                Unknown
# 2                 NaN               IMC                 Cruise
# 3                 0.0               IMC                 Cruise
# 4                 0.0               VMC               Approach
# ...               ...               ...                    ...
# 90343             0.0               NaN                    NaN
# 90344             0.0               NaN                    NaN
# 90345             1.0               VMC                    NaN
# 90346             0.0               NaN                    NaN
# 90347             1.0               NaN                    NaN
#
#         Report.Status Publication.Date
# 0      Probable Cause              NaN
# 1      Probable Cause       19-09-1996
# 2      Probable Cause       26-02-2007
# 3      Probable Cause       12-09-2000
# 4      Probable Cause       16-04-1980
# ...               ...              ...
# 90343             NaN       29-12-2022
# 90344             NaN              NaN
# 90345             NaN       27-12-2022
# 90346             NaN              NaN
# 90347             NaN       30-12-2022
#
# [88958 rows x 31 columns]

# %% [markdown]
# Checking for duplicate values after dropping.

# %%
df.duplicated().sum()
# Out:
# 1390

# %% [markdown]
# Replacing missing values with a zero in the following columns.

# %%
df['Total.Fatal.Injuries'] = df['Total.Fatal.Injuries'].fillna(0)
df['Total.Serious.Injuries'] = df['Total.Serious.Injuries'].fillna(0)
df['Total.Minor.Injuries'] = df['Total.Minor.Injuries'].fillna(0)
df['Total.Uninjured'] = df['Total.Uninjured'].fillna(0)
df['Number.of.Engines'] = df['Number.of.Engines'].fillna(0)

# %% [markdown]
# Dropping all the missing values in the following columns.

# %%
df.dropna(subset=['Make'], inplace=True)
df.dropna(subset=['Model'], inplace=True)
df.dropna(subset=['Engine.Type'], inplace=True)
df.dropna(subset=['Aircraft.Category'], inplace=True)
df.dropna(subset=['Aircraft.damage'], inplace=True)

# %% [markdown]
# Combining Make and Model as one column

# %%
df['Air_craft'] = df['Make'] + " " + df['Model']

# %% [markdown]
# Checking if the newly created column is in our dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26057 entries, 5 to 90226
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                26057 non-null  object
#  1   Investigation.Type      26057 non-null  object
#  2   Accident.Number         26057 non-null  object
#  3   Event.Date              26057 non-null  object
#  4   Location                26051 non-null  object
#  5   Country                 26046 non-null  object
#  6   Latitude                21865 non-null  object
#  7   Longitude               21854 non-null  object
#  8   Airport.Code            17154 non-null  object
#  9   Airport.Name            17886 non-null  object
#  10  Injury.Severity         25981 non-null  object
#  11  Aircraft.damage         26057 non-null  object
#  12  Aircraft.Category       26057 non-null  object
#  13  Registration.Number     25958 non-null  object
#  14  Make                    26057 non-null  object
#  15  Model                   26057 non-null  object
#  16  Amateur.Built           26050 non-null  object
#  17  Number.of.Engines       26057 non-null  float64
#  18  Engine.Type             26057 non-null  object
#  19  FAR.Description         25946 non-null  object
#  20  Schedule                1995 non-null   object
#  21  Purpose.of.flight       24618 non-null  object
#  22  Air.carrier             10703 non-null  object
#  23  Total.Fatal.Injuries    26057 non-null  float64
#  24  Total.Serious.Injuries  26057 non-null  float64
#  25  Total.Minor.Injuries    26057 non-null  float64
#  26  Total.Uninjured         26057 non-null  float64
#  27  Weather.Condition       25401 non-null  object
#  28  Broad.phase.of.flight   7115 non-null   object
#  29  Report.Status           24727 non-null  object
#  30  Publication.Date        24540 non-null  object
#  31  Air_craft               26057 non-null  object
# dtypes: float64(5), object(27)
# memory usage: 6.6+ MB

# %% [markdown]
# Filtering

# %%
Df = df[['Injury.Severity','Aircraft.damage','Aircraft.Category','Air_craft','Amateur.Built','Number.of.Engines','Engine.Type','Total.Fatal.Injuries','Total.Serious.Injuries','Total.Minor.Injuries','Total.Uninjured','Weather.Condition']]
Df
# Out:
#       Injury.Severity Aircraft.damage Aircraft.Category  \
# 5           Non-Fatal     Substantial          Airplane
# 7           Non-Fatal     Substantial          Airplane
# 8           Non-Fatal     Substantial          Airplane
# 12          Non-Fatal       Destroyed          Airplane
# 13           Fatal(1)       Destroyed          Airplane
# ...               ...             ...               ...
# 90098       Non-Fatal     Substantial          Airplane
# 90106       Non-Fatal     Substantial          Airplane
# 90120       Non-Fatal     Substantial          Airplane
# 90194           Minor     Substantial          Airplane
# 90226       Non-Fatal     Substantial          Airplane
#
#                       Air_craft Amateur.Built  Number.of.Engines  \
# 5         Mcdonnell Douglas DC9            No                2.0
# 7                    Cessna 140            No                1.0
# 8                   Cessna 401B            No                2.0
# 12              Bellanca 17-30A            No                1.0
# 13                 Cessna R172K            No                1.0
# ...                         ...           ...                ...
# 90098                CESSNA 150            No                1.0
# 90106              CESSNA 177RG            No                1.0
# 90120                BEECH B-60            No                2.0
# 90194  STEPHEN J HOFFMAN MS-500           Yes                1.0
# 90226               LUSCOMBE 8E            No                1.0
#
#          Engine.Type  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 5          Turbo Fan                   0.0                     0.0
# 7      Reciprocating                   0.0                     0.0
# 8      Reciprocating                   0.0                     0.0
# 12     Reciprocating                   0.0                     0.0
# 13     Reciprocating                   1.0                     0.0
# ...              ...                   ...                     ...
# 90098  Reciprocating                   0.0                     0.0
# 90106  Reciprocating                   0.0                     0.0
# 90120  Reciprocating                   0.0                     0.0
# 90194  Reciprocating                   0.0                     1.0
# 90226  Reciprocating                   0.0                     0.0
#
#        Total.Minor.Injuries  Total.Uninjured Weather.Condition
# 5                       1.0             44.0               VMC
# 7                       0.0              2.0               VMC
# 8                       0.0              2.0               IMC
# 12                      1.0              0.0               IMC
# 13                      0.0              0.0               IMC
# ...                     ...              ...               ...
# 90098                   0.0              1.0               VMC
# 90106                   0.0              2.0               VMC
# 90120                   0.0              1.0               VMC
# 90194                   0.0              0.0               VMC
# 90226                   0.0              2.0               VMC
#
# [26057 rows x 12 columns]

# %% [markdown]
# Checking for missing values in the newly created dataframe.

# %%
Df.isna().sum()
# Out:
# Injury.Severity            76
# Aircraft.damage             0
# Aircraft.Category           0
# Air_craft                   0
# Amateur.Built               7
# Number.of.Engines           0
# Engine.Type                 0
# Total.Fatal.Injuries        0
# Total.Serious.Injuries      0
# Total.Minor.Injuries        0
# Total.Uninjured             0
# Weather.Condition         656
# dtype: int64

# %% [markdown]
# Checking for duplicate values in our newly created dataframe.

# %%
Df.duplicated().sum()
# Out:
# 8720

# %% [markdown]
# Dropping duplicate values and renaming our cleaned dataframe.

# %%
Cleaned_df = Df.drop_duplicates()
Cleaned_df
# Out:
#       Injury.Severity Aircraft.damage  Aircraft.Category  \
# 5           Non-Fatal     Substantial           Airplane
# 7           Non-Fatal     Substantial           Airplane
# 8           Non-Fatal     Substantial           Airplane
# 12          Non-Fatal       Destroyed           Airplane
# 13           Fatal(1)       Destroyed           Airplane
# ...               ...             ...                ...
# 90028         Serious     Substantial  Powered Parachute
# 90030           Minor     Substantial           Airplane
# 90096       Non-Fatal     Substantial           Airplane
# 90120       Non-Fatal     Substantial           Airplane
# 90194           Minor     Substantial           Airplane
#
#                                   Air_craft Amateur.Built  Number.of.Engines  \
# 5                     Mcdonnell Douglas DC9            No                2.0
# 7                                Cessna 140            No                1.0
# 8                               Cessna 401B            No                2.0
# 12                          Bellanca 17-30A            No                1.0
# 13                             Cessna R172K            No                1.0
# ...                                     ...           ...                ...
# 90028                           DESTINY XLT            No                1.0
# 90030           HIBBARD NORMAN E THORP T-18           Yes                1.0
# 90096  WASZAK ARTHUR B WITTMAN TAILWIND W10           Yes                1.0
# 90120                            BEECH B-60            No                2.0
# 90194              STEPHEN J HOFFMAN MS-500           Yes                1.0
#
#          Engine.Type  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 5          Turbo Fan                   0.0                     0.0
# 7      Reciprocating                   0.0                     0.0
# 8      Reciprocating                   0.0                     0.0
# 12     Reciprocating                   0.0                     0.0
# 13     Reciprocating                   1.0                     0.0
# ...              ...                   ...                     ...
# 90028  Reciprocating                   0.0                     1.0
# 90030  Reciprocating                   0.0                     1.0
# 90096  Reciprocating                   0.0                     0.0
# 90120  Reciprocating                   0.0                     0.0
# 90194  Reciprocating                   0.0                     1.0
#
#        Total.Minor.Injuries  Total.Uninjured Weather.Condition
# 5                       1.0             44.0               VMC
# 7                       0.0              2.0               VMC
# 8                       0.0              2.0               IMC
# 12                      1.0              0.0               IMC
# 13                      0.0              0.0               IMC
# ...                     ...              ...               ...
# 90028                   1.0              0.0               VMC
# 90030                   0.0              0.0               VMC
# 90096                   0.0              1.0               VMC
# 90120                   0.0              1.0               VMC
# 90194                   0.0              0.0               VMC
#
# [17337 rows x 12 columns]

# %%
Cleaned_df.duplicated().sum()
# Out:
# 0

# %%
Cleaned_df
# Out:
#       Injury.Severity Aircraft.damage  Aircraft.Category  \
# 5           Non-Fatal     Substantial           Airplane
# 7           Non-Fatal     Substantial           Airplane
# 8           Non-Fatal     Substantial           Airplane
# 12          Non-Fatal       Destroyed           Airplane
# 13           Fatal(1)       Destroyed           Airplane
# ...               ...             ...                ...
# 90028         Serious     Substantial  Powered Parachute
# 90030           Minor     Substantial           Airplane
# 90096       Non-Fatal     Substantial           Airplane
# 90120       Non-Fatal     Substantial           Airplane
# 90194           Minor     Substantial           Airplane
#
#                                   Air_craft Amateur.Built  Number.of.Engines  \
# 5                     Mcdonnell Douglas DC9            No                2.0
# 7                                Cessna 140            No                1.0
# 8                               Cessna 401B            No                2.0
# 12                          Bellanca 17-30A            No                1.0
# 13                             Cessna R172K            No                1.0
# ...                                     ...           ...                ...
# 90028                           DESTINY XLT            No                1.0
# 90030           HIBBARD NORMAN E THORP T-18           Yes                1.0
# 90096  WASZAK ARTHUR B WITTMAN TAILWIND W10           Yes                1.0
# 90120                            BEECH B-60            No                2.0
# 90194              STEPHEN J HOFFMAN MS-500           Yes                1.0
#
#          Engine.Type  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 5          Turbo Fan                   0.0                     0.0
# 7      Reciprocating                   0.0                     0.0
# 8      Reciprocating                   0.0                     0.0
# 12     Reciprocating                   0.0                     0.0
# 13     Reciprocating                   1.0                     0.0
# ...              ...                   ...                     ...
# 90028  Reciprocating                   0.0                     1.0
# 90030  Reciprocating                   0.0                     1.0
# 90096  Reciprocating                   0.0                     0.0
# 90120  Reciprocating                   0.0                     0.0
# 90194  Reciprocating                   0.0                     1.0
#
#        Total.Minor.Injuries  Total.Uninjured Weather.Condition
# 5                       1.0             44.0               VMC
# 7                       0.0              2.0               VMC
# 8                       0.0              2.0               IMC
# 12                      1.0              0.0               IMC
# 13                      0.0              0.0               IMC
# ...                     ...              ...               ...
# 90028                   1.0              0.0               VMC
# 90030                   0.0              0.0               VMC
# 90096                   0.0              1.0               VMC
# 90120                   0.0              1.0               VMC
# 90194                   0.0              0.0               VMC
#
# [17337 rows x 12 columns]
